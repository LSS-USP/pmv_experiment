# %% [markdown]
# # Query feita:
#
# ```xml
# <union>
#   <id-query ref="2352453459" type="node"/>
#   <id-query ref="2468334935" type="node"/>
#   <id-query ref="1828182282" type="node"/>
#   <id-query ref="1828182278" type="node"/>
#   <id-query ref="926015572" type="node"/>
#   <id-query ref="926015573" type="node"/>
#   <id-query ref="2454667297" type="node"/>
#   <id-query ref="2441819611" type="node"/>
#   <id-query ref="4252369893" type="node"/>
#   <id-query ref="140822925" type="node"/>
#   <id-query ref="299610785" type="node"/>
#   <id-query ref="466070945" type="node"/>
#   <id-query ref="28148374" type="node"/>
#   <recurse type="down"/>
# </union>
# <print>
# ```
#
# # Resposta
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <osm version="0.6" generator="Overpass API 0.7.55.4 3079d8ea">
# <note>The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.</note>
# <meta osm_base="2018-08-10T14:11:02Z"/>
#
#   <node id="28148374" lat="-23.5687902" lon="-46.6863364">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="140822925" lat="-23.5851163" lon="-46.6830816">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="299610785" lat="-23.5850592" lon="-46.6828715">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="466070945" lat="-23.5686866" lon="-46.6863935">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="926015572" lat="-23.5556394" lon="-46.7052278">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="926015573" lat="-23.5555253" lon="-46.7050122">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="1828182278" lat="-23.5399299" lon="-46.6752677">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="1828182282" lat="-23.5398252" lon="-46.6754278">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="2352453459" lat="-23.5844291" lon="-46.6363091">
#     <tag k="bicycle" v="yes"/>
#     <tag k="crossing" v="traffic_signals"/>
#     <tag k="highway" v="crossing"/>
#   </node>
#   <node id="2441819611" lat="-23.5555530" lon="-46.6493791">
#     <tag k="crossing_ref" v="zebra"/>
#     <tag k="highway" v="crossing"/>
#     <tag k="source" v="Bing"/>
#     <tag k="uncontrolled" v="yes"/>
#   </node>
#   <node id="2454667297" lat="-23.5445604" lon="-46.6571247">
#     <tag k="crossing" v="zebra"/>
#     <tag k="highway" v="crossing"/>
#   </node>
#   <node id="2468334935" lat="-23.5847779" lon="-46.6364230">
#     <tag k="highway" v="traffic_signals"/>
#   </node>
#   <node id="4252369893" lat="-23.5553728" lon="-46.6495504">
#     <tag k="crossing_ref" v="zebra"/>
#     <tag k="highway" v="crossing"/>
#     <tag k="source" v="Bing"/>
#     <tag k="uncontrolled" v="yes"/>
#   </node>
#
# </osm>
#
# ```

# %% [markdown]
# # Posicionamento das PMVs
#
# ![Mapa com PMVs](pmvs_locations.png)
